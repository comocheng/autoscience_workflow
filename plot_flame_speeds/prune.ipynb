# %%
# figure out how to reduce grid points so the thing will solve

# %%
import cantera as ct
import os

# %%
gas = ct.Solution('/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_model/chem_annotated.cti')

# %%
flame = ct.FreeFlame(gas, width=0.08)

h5_filepath_guess = os.path.join("/work/westgroup/harris.se/autoscience/reaction_calculator/plot_flame_speeds/base_rmg", f"saved_flame_0.h5")

arr2 = ct.SolutionArray(gas)
# the flame domain needs to be specified as subgroup
arr2.read_hdf(h5_filepath_guess, group="freeflame", subgroup="flame", force=True)


flame.set_initial_guess(data=arr2)

# %%
flame.max_grid_points = 10000

# %%
dir(flame)
# Out:
# ['L',
#  'P',
#  'T',
#  'V',
#  'X',
#  'Y',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '_get_indices',
#  '_get_initial_solution',
#  '_interrupt',
#  '_other',
#  '_steady_callback',
#  '_time_step_callback',
#  'boundary_emissivities',
#  'chemical_potentials',
#  'clear_stats',
#  'collect_data',
#  'concentrations',
#  'cp',
#  'cp_mass',
#  'cp_mole',
#  'creation_rates',
#  'cv',
#  'cv_mass',
#  'cv_mole',
#  'delta_enthalpy',
#  'delta_entropy',
#  'delta_gibbs',
#  'delta_standard_enthalpy',
#  'delta_standard_entropy',
#  'delta_standard_gibbs',
#  'density',
#  'density_mass',
# ...

# %%
flame.max_grid_points
# Out:
# 10000

# %%
dir(arr2)
# Out:
# ['DP',
#  'DPQ',
#  'DPX',
#  'DPY',
#  'HP',
#  'HPQ',
#  'HPX',
#  'HPY',
#  'ID',
#  'P',
#  'PQ',
#  'PV',
#  'PX',
#  'P_sat',
#  'Q',
#  'SH',
#  'SP',
#  'SPQ',
#  'SPX',
#  'SPY',
#  'ST',
#  'SV',
#  'SVQ',
#  'SVX',
#  'SVY',
#  'T',
#  'TD',
#  'TDQ',
#  'TDX',
#  'TDY',
#  'TH',
#  'TP',
#  'TPQ',
#  'TPX',
#  'TPY',
#  'TQ',
#  'TV',
#  'TX',
#  'T_sat',
#  'UP',
#  'UV',
#  'UVQ',
#  'UVX',
#  'UVY',
#  'VH',
#  'X',
#  'Y',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_call_scalar',
#  '_extra',
#  '_indices',
#  '_interface_n_species',
# ...

# %%
arr2[0]['max_grid_points']
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_27291/2544726496.py in <module>
# ----> 1 arr2[0]['max_grid_points']
#
# /work/westgroup/harris.se/tst_env/lib/python3.7/site-packages/cantera/composite.py in __getitem__(self, index)
#     588
#     589     def __getitem__(self, index):
# --> 590         states = self._states[index]
#     591         if(isinstance(states, list)):
#     592             num_rows = len(states)
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
flame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_27291/136158172.py in <module>
# ----> 1 flame
#
# NameError: name 'flame' is not defined
