# %%
import os
import rmgpy.chemkin
import quicksim
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
chemkin = '/projects/westgroup/harris.se/autoscience/fuels/butane/official/butane_20240501/chem_annotated.inp'
chemkin = '/projects/westgroup/harris.se/autoscience/fuels/butane/fresh_autoscience/RMG_min/butane_20260112/chem_annotated.inp'


spec_dict = os.path.join(os.path.dirname(chemkin), 'species_dictionary.txt')

species_list, reaction_list = rmgpy.chemkin.load_chemkin_file(chemkin, spec_dict)

# %%
# Ts = np.array([700, 830, 950])
Ts = np.array([830])
delays = np.zeros(len(Ts))
for i in range(len(Ts)):
    times, P, X, failed = quicksim.run_quicksim(species_list, reaction_list, Ts[i])
    delays[i] = quicksim.get_ignition_delay_time(times, P)

    plt.plot(times, P)
    # plt.axvline(x=delay, color='black')
    plt.xscale('log')
# Out:
# Wrote YAML mechanism file to 'temp.yaml'.
# Mechanism contains 277 species and 5921 reactions.
# Validating mechanism...
# PASSED
# Running quicksim with T=830, P=1013250.0, X=None

# %%
T7 = np.array([700, 701, 731, 732, 756, 757, 794, 795, 840, 849, 872, 881, 906,
       926, 929, 959])
experiment7 = np.array([0.0865 , 0.0739 , 0.0313 , 0.033  , 0.0309 , 0.03   , 0.056  ,
       0.0566 , 0.0679 , 0.0664 , 0.0652 , 0.0671 , 0.047  , 0.0279 ,
       0.02805, 0.012  ])



rmg_min_1_long = np.array([0.03370763, 0.0265366 , 0.02128309, 0.01739802, 0.01447301,
       0.01232028, 0.01073352, 0.00959442, 0.00879581, 0.00826659,
       0.00795157, 0.00845332, 0.00783275, 0.0079856 , 0.00837084,
       0.00863783, 0.00912065, 0.00970145, 0.01037533, 0.01114494,
       0.01201435, 0.01299718, 0.01412427, 0.01545466, 0.01705906,
       0.0188886 , 0.02066769, 0.02208995, 0.02298717, 0.02333202,
       0.02318088, 0.02262682, 0.02176891, 0.02069724, 0.01948735,
       0.01819953, 0.01688029, 0.01556453, 0.01427783, 0.01303839,
       0.01185869, 0.01074679, 0.00970735, 0.00874243, 0.00785211,
       0.00703499, 0.0062886 , 0.0056097 , 0.00499452, 0.00443903,
       0.003939  ])
rmg_min_2_long = np.array([0.02191942, 0.01731967, 0.0138689 , 0.01126609, 0.00929474,
       0.00779893, 0.00666447, 0.00580799, 0.00516776, 0.00469831,
       0.00436587, 0.00414542, 0.00401823, 0.00397049, 0.00399185,
       0.00407471, 0.00421323, 0.00440303, 0.00464064, 0.00492325,
       0.00524857, 0.00561461, 0.00601957, 0.00646141, 0.0069367 ,
       0.00743828, 0.00795152, 0.00845081, 0.00890075, 0.00926446,
       0.00951385, 0.00963475, 0.00962546, 0.00949324, 0.00925092,
       0.00891463, 0.00850233, 0.00803256, 0.00752342, 0.00699168,
       0.0064521 , 0.00591704, 0.00539637, 0.00489753, 0.00442578,
       0.00398449, 0.00357547, 0.00319932, 0.00285568, 0.00254352,
       0.00226134])

rmg_min_3 = np.array([0.00684799, 0.00669673, 0.0039745 , 0.00392358, 0.0031468 ,
       0.00313633, 0.00308694, 0.00309876, 0.00427588, 0.00468218,
       0.00608206, 0.00679356, 0.00872839, 0.00927382, 0.00926104,
       0.00818746])
rmg_min_3 = np.array([0.01773118, 0.01399649, 0.01118769, 0.00906622, 0.00745755,
       0.01593367, 0.01359253, 0.01160668, 0.00992154, 0.00849068,
       0.00727475, 0.00624049, 0.00535985, 0.00460918, 0.00396855,
       0.00342124])
rmg_min_8 = np.array([0.09059837, 0.07474184, 0.06294471, 0.05426873, 0.04806848,
       0.04391832, 0.04156676, 0.04091379, 0.04200859, 0.04506429,
       0.05049088, 0.05891825, 0.07105349, 0.08688056, 0.10481062,
       0.12705486, 0.16374257, 0.21240882, 0.24611322, 0.2583586 ,
       0.25467824, 0.24109964, 0.22208886, 0.20064518, 0.17869101,
       0.15740927, 0.13748709, 0.11928313, 0.10294104, 0.08846636,
       0.07577907, 0.06474971, 0.05522386, 0.04703871, 0.04003368,
       0.03405703, 0.0289695 , 0.02464597, 0.02097578, 0.01786227,
       0.01522174, 0.01298228, 0.01108241, 0.00946985, 0.00810024,
       0.00693605, 0.00594557, 0.00510208, 0.00438302, 0.00376938,
       0.00324519])
rmg_min_9 = np.array([0.09937269, 0.08706007, 0.07980979, 0.07713015, 0.07909323,
       0.08648023, 0.10116011, 0.12703003, 0.17217313, 0.25214076,
       0.37745875, 0.5450627 , 0.74697534, 0.86945433, 0.89785017,
       0.86352196, 0.79472066, 0.7107045 , 0.62332398, 0.53932494,
       0.46217865, 0.39334954, 0.33312401, 0.2811357 , 0.23668916,
       0.19895435, 0.16707916, 0.14025137, 0.11772941, 0.09885467,
       0.0830533 , 0.06983187, 0.05877032, 0.04951365, 0.04176341,
       0.03526975, 0.02982404, 0.02525244, 0.02141029, 0.01817727,
       0.01545333, 0.01315527, 0.01121389, 0.00957159, 0.00818037,
       0.00700024, 0.00599779, 0.00514514, 0.00441894, 0.00379963,
       0.00327085])
Tmax = 1077  # use min and max temperature range of the data: 663K-1077K
Tmin = 663
N = 51
temperatures = np.linspace(Tmin, Tmax, N)

# %%
# plot the ignition delay

colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

linewidths = np.linspace(0.4, 4.0, 9)

plt.plot(1000.0 / temperatures, rmg_min_1_long, label='RMG-min-1', color=colors[0], linewidth=linewidths[0])
plt.plot(1000.0 / temperatures, rmg_min_2_long, label='RMG-min-2', color=colors[0], linewidth=linewidths[1])
plt.plot(1000.0 / temperatures, rmg_min_3, label='RMG-min-3', color=colors[0], linewidth=linewidths[2])
plt.plot(1000.0 / temperatures, rmg_min_4, label='RMG-min-4', color=colors[0], linewidth=linewidths[3])
plt.plot(1000.0 / temperatures, rmg_min_5, label='RMG-min-5', color=colors[0], linewidth=linewidths[4])
plt.plot(1000.0 / T7, rmg_min_6, label='RMG-min-6', color=colors[0], linewidth=linewidths[5])
plt.plot(1000.0 / temperatures, rmg_min_7, label='RMG-min-7', color=colors[0], linewidth=linewidths[6])
plt.plot(1000.0 / temperatures, rmg_min_8, label='RMG-min-8', color=colors[0], linewidth=linewidths[7])
plt.plot(1000.0 / temperatures, rmg_min_9, label='RMG-min-9', color=colors[0], linewidth=linewidths[8])

plt.scatter(1000.0 / Ts, delays, marker='*', label='THIS RUN')

plt.scatter(1000.0 / T7, experiment7, color='black', label='experiment')

ax = plt.gca()
ax.set_yscale('log')
plt.legend()

plt.title('Ignition Delays Phi=1.0')
plt.xlabel('1000K / T')
plt.ylabel('Delay (s)')
plt.legend(bbox_to_anchor=(1, 1))
