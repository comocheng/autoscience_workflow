# %%
import os
import copy
import cantera as ct
import numpy as np
import pandas as pd
import concurrent.futures
import rmgpy.chemkin
import pickle


import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load base data

base_rmg7 = np.array([0.04908328, 0.04854439, 0.04814446, 0.04868176, 0.075588  ,
       0.07737167, 0.14791668, 0.14857535, 0.1085917 , 0.0952434 ,
       0.06520823, 0.05563237, 0.03535775, 0.02462961, 0.02334903,
       0.01398333])  # 24 hour RMG run - 110 species

aramco7 = np.array([0.03945921, 0.03874611, 0.02817182, 0.02812066, 0.03236667,
       0.03278732, 0.06009581, 0.06085926, 0.06020536, 0.05459522,
       0.03965133, 0.03435827, 0.02245863, 0.01580939, 0.01499945,
       0.00896072])
experiment7 = np.array([0.0865 , 0.0739 , 0.0313 , 0.033  , 0.0309 , 0.03   , 0.056  ,
       0.0566 , 0.0679 , 0.0664 , 0.0652 , 0.0671 , 0.047  , 0.0279 ,
       0.02805, 0.012  ])

# %%
# Load the experimental conditions
ignition_delay_data = '/work/westgroup/harris.se/autoscience/autoscience/butane/experimental_data/butane_ignition_delay.csv'
ignition_delay_data = '/home/moon/autoscience/autoscience/butane/experimental_data/butane_ignition_delay.csv'
df_exp = pd.read_csv(ignition_delay_data)

# slice just table 7, where phi=1.0
table7 = df_exp[df_exp['Table'] == 7]
# Define Initial conditions using experimental data
tau7 = table7['time (ms)'].values.astype(float)  # ignition delay
T7 = table7['T_C'].values  # Temperatures
P7 = table7['nominal pressure(atm)'].values * ct.one_atm  # pressures in atm


# list of starting conditions
# Mixture compositions taken from table 2 of
# https://doi-org.ezproxy.neu.edu/10.1016/j.combustflame.2010.01.016
concentrations = []
# for phi = 1
x_diluent = 0.7649
conc_dict = {
    'O2(2)': 0.2038,
    'butane(1)': 0.03135
}

for i in range(0, len(table7)):
    x_N2 = table7['%N2'].values[i] / 100.0 * x_diluent
    x_Ar = table7['%Ar'].values[i] / 100.0 * x_diluent
    x_CO2 = table7['%CO2'].values[i] / 100.0 * x_diluent
    conc_dict['N2'] = x_N2
    conc_dict['Ar'] = x_Ar
    conc_dict['CO2(7)'] = x_CO2
    concentrations.append(conc_dict)

# %%
# plot the ignition delay
plt.plot(1000.0 / T7, base_rmg7, marker='x', linestyle='dashed')
plt.plot(1000.0 / T7, aramco7, marker='x')
plt.scatter(1000.0 / T7, tau7 / 1000.0, color='black')
ax = plt.gca()
ax.set_yscale('log')
plt.legend(['Base RMG', 'Aramco', 'Experiment'])
plt.title('Ignition Delays Phi=1.0')
plt.xlabel('1000K / T')
plt.ylabel('Delay (s)')
plt.savefig('table7.png')
# plt.legend(bbox_to_anchor=(0, 1), , ncol=1)

# %%
# get the mapping from cantera base back to RMG
# load the sensitive parameters
chemkin = '/home/moon/autoscience/reaction_calculator/delay_uncertainty/base_model/chem_annotated.inp'
working_dir = os.path.dirname(chemkin)
transport = os.path.join(working_dir, 'tran.dat')
species_dict = os.path.join(working_dir, 'species_dictionary.txt')
species_list, reaction_list = rmgpy.chemkin.load_chemkin_file(chemkin, dictionary_path=species_dict, transport_path=transport, use_chemkin_names=True)

base_gas = ct.Solution(os.path.join(working_dir, 'base.cti'))

# Check that species order is preserved
for i in range(len(species_list)):
    assert str(species_list[i]) == base_gas.species_names[i]

# %%
def same_reaction(rmg_rxn, ct_rxn):
    rmg_r = set([str(x) for x in rmg_rxn.reactants])
    rmg_p = set([str(x) for x in rmg_rxn.products])
    
    ct_r = set(ct_rxn.reactants.keys())
    ct_p = set(ct_rxn.products.keys())
    return rmg_r == ct_r and rmg_p == ct_p

# %%
# this takes a really long time to run, so try loading the file first
if os.path.exists('ct2rmg_rxn.pickle'):
    with open('ct2rmg_rxn.pickle', 'rb') as handle:
        ct2rmg_rxn = pickle.load(handle)
else:
    ct2rmg_rxn = {}
    for i in range(len(base_gas.reactions())):
        try:
            if same_reaction(reaction_list[i], base_gas.reactions()[i]):
                ct2rmg_rxn[i] = i
                continue
        except IndexError:
            pass

        for j in range(len(reaction_list)):
            if same_reaction(reaction_list[j], base_gas.reactions()[i]):
                ct2rmg_rxn[i] = j
                break
        else:
            print('no match found!', base_gas.reactions()[i])
    # save the result
    with open('ct2rmg_rxn.pickle', 'wb') as handle:
        pickle.dump(ct2rmg_rxn, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
len(ct2rmg_rxn)
# Out:
# 1850

# %%
# load the parameter uncertainties
thermo_uncertainty_file = '/home/moon/autoscience/autoscience/paper/models/base_rmg/thermo_uncertainty.npy'
kinetic_uncertainty_file = '/home/moon/autoscience/autoscience/paper/models/base_rmg/kinetic_uncertainty.npy'


thermo_uncertainties_rmg = np.load(thermo_uncertainty_file)
kinetic_uncertainties_rmg = np.load(kinetic_uncertainty_file)


thermo_uncertainties_ct = thermo_uncertainties_rmg  # there's a one to one correspondence
kinetic_uncertainties_ct = np.zeros(len(base_gas.reactions()))
# need to go from cantera reaction to rmg reaction
for i in range(len(kinetic_uncertainties_ct)):
    rmg_index = ct2rmg_rxn[i]
    kinetic_uncertainties_ct[i] = kinetic_uncertainties_rmg[rmg_index]

# %%
# load the parameter delays
table_index = 7
# condition_index = 7

# species_delays = base_rmg7[table_index] + (np.random.random((len(base_gas.species()), len(concentrations))) / 1e4)
# reaction_delays = base_rmg7[table_index] + (np.random.random((len(base_gas.reactions()), len(concentrations))) / 1e5)

species_delays = np.load(os.path.join(working_dir, f'species_delays_{table_index:04}.npy'))
reaction_delays = np.load(os.path.join(working_dir, f'reaction_delays_{table_index:04}.npy'))

# %%
for i in range(reaction_delays.shape[0]):
    if reaction_delays[i, 0] == 0:
        rmg_index = ct2rmg_rxn[i]
        try:
            family = reaction_list[rmg_index].family
        except AttributeError:
            continue
        try:
            a = reaction_list[rmg_index].kinetics.A.value
        except AttributeError:
            continue
        print(f'Missing answer for RMG reaction {rmg_index} and not PDEP')
        print(reaction_list[rmg_index].family)
# Out:
# Missing answer for RMG reaction 1073 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1075 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1076 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1077 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1078 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1079 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1080 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1081 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1082 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1083 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1084 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1085 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1086 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1087 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1088 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1089 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1090 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1091 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1092 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1093 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1094 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1095 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1096 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1097 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1098 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1099 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1100 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1101 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1102 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1103 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1108 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1109 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1110 and not PDEP
# CO_Disproportionation
# Missing answer for RMG reaction 1111 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1112 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1113 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1114 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1115 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1116 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1117 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1118 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1119 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1120 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1121 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1122 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1123 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1130 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1151 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1152 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1154 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1157 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1158 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1159 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1160 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1161 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1162 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1163 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1164 and not PDEP
# CO_Disproportionation
# Missing answer for RMG reaction 1165 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1166 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1167 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1168 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1169 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1170 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1171 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1173 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1174 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1175 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1176 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1177 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1178 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1179 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1180 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1181 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1182 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1183 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1185 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1186 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1187 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1188 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1190 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1191 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1195 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1196 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1201 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1204 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1205 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1212 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1213 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1214 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1215 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1216 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1217 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1218 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1219 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1220 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1221 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1222 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1223 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1224 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1225 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1226 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1227 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1228 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1229 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1230 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1231 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1232 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1241 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1242 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1243 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1244 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1245 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1247 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1248 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1249 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1250 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1251 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1252 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1253 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1254 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1255 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1256 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1257 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1258 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1259 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1261 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1262 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1263 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1264 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1265 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1266 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1267 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1279 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1280 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1281 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1282 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1283 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1284 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1285 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1286 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1287 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1288 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1289 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1290 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1291 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1292 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1293 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1294 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1295 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1296 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1297 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1298 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1299 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1300 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1301 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1302 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1303 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1304 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1305 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1306 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1307 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1308 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1309 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1310 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1311 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1312 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1313 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1314 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1315 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1316 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1317 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1318 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1319 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1320 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1321 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1322 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1323 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1324 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1325 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1326 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1327 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1328 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1329 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1330 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1336 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1337 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1338 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1339 and not PDEP
# CO_Disproportionation
# Missing answer for RMG reaction 1340 and not PDEP
# CO_Disproportionation
# Missing answer for RMG reaction 1341 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1342 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1343 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1344 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1345 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1346 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1347 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1348 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1349 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1350 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1351 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1352 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1353 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1354 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1355 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1356 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1357 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1358 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1360 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1362 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1363 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1364 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1365 and not PDEP
# CO_Disproportionation
# Missing answer for RMG reaction 1366 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1367 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1368 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1369 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1370 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1371 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1372 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1373 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1374 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1388 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1397 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1398 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1399 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1401 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1402 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1405 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1406 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1407 and not PDEP
# CO_Disproportionation
# Missing answer for RMG reaction 1408 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1409 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1410 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1411 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1412 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1413 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1424 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1425 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1426 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1427 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1428 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1429 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1432 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1433 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1434 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1435 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1436 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1437 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1438 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1439 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1440 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1441 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1442 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1443 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1444 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1445 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1446 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1447 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1448 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1467 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1470 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1471 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1472 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1473 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1475 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1484 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1485 and not PDEP
# FFCM1(-)
# Missing answer for RMG reaction 1486 and not PDEP
# FFCM1(-)
# Missing answer for RMG reaction 1487 and not PDEP
# FFCM1(-)
# Missing answer for RMG reaction 1488 and not PDEP
# FFCM1(-)
# Missing answer for RMG reaction 1489 and not PDEP
# FFCM1(-)
# Missing answer for RMG reaction 1490 and not PDEP
# FFCM1(-)
# Missing answer for RMG reaction 1491 and not PDEP
# FFCM1(-)
# Missing answer for RMG reaction 1492 and not PDEP
# FFCM1(-)
# Missing answer for RMG reaction 1493 and not PDEP
# FFCM1(-)
# Missing answer for RMG reaction 1494 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1495 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1496 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1497 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1498 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1499 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1500 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1501 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1502 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1503 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1504 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1505 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1506 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1507 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1508 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1509 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1510 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1511 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1512 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1513 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1514 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1515 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1516 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1519 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1520 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1521 and not PDEP
# CO_Disproportionation
# Missing answer for RMG reaction 1522 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1523 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1524 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1525 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1526 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1527 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1528 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1529 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1530 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1531 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1532 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1533 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1534 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1535 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1536 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1537 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1538 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1539 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1540 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1541 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1542 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1543 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1544 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1545 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1546 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1547 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1548 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1549 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1550 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1551 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1552 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1553 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1554 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1555 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1556 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1557 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1558 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1559 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1561 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1562 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1563 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1564 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1565 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1566 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1567 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1572 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1573 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1576 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1577 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1578 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1579 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1580 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1581 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1582 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1583 and not PDEP
# CO_Disproportionation
# Missing answer for RMG reaction 1584 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1585 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1586 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1587 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1588 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1589 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1590 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1591 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1592 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1593 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1594 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1595 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1596 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1597 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1598 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1599 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1600 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1601 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1602 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1606 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1607 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1613 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1614 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1615 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1616 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1617 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1618 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1619 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1621 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1624 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1625 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1627 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1628 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1629 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1630 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1631 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1632 and not PDEP
# CO_Disproportionation
# Missing answer for RMG reaction 1633 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1634 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1635 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1636 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1637 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1638 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1639 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1640 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1641 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1642 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1643 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1644 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1645 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1646 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1647 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1648 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1649 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1650 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1651 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1652 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1653 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1654 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1655 and not PDEP
# Klippenstein_Glarborg2016
# Missing answer for RMG reaction 1656 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1657 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1658 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1659 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1660 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1661 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1662 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1663 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1664 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1665 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1666 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1667 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1670 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1671 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1672 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1674 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1680 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1681 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1682 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1683 and not PDEP
# CO_Disproportionation
# Missing answer for RMG reaction 1684 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1685 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1686 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1687 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1688 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1689 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1690 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1691 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1692 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1693 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1694 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1695 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1698 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1699 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1700 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1701 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1702 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1703 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1704 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1705 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1706 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1707 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1708 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1709 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1710 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1711 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1712 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1713 and not PDEP
# CurranPentane
# Missing answer for RMG reaction 1714 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1715 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1716 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1717 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1718 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1719 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1720 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1721 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1722 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1723 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1724 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1725 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1726 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1727 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1728 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1729 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1730 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1731 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1732 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1733 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1734 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1735 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1736 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1737 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1738 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1739 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1740 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1741 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1742 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1743 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1744 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1745 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1746 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1747 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1748 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1749 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1753 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1754 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1755 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1756 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1757 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1758 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1759 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1760 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1761 and not PDEP
# CO_Disproportionation
# Missing answer for RMG reaction 1762 and not PDEP
# CO_Disproportionation
# Missing answer for RMG reaction 1763 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1764 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1765 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1766 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1767 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1768 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1769 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1770 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1771 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1772 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1773 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1774 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1775 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1776 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1777 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1778 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1779 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1780 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1781 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1782 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1783 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1784 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1785 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1786 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1787 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1788 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1789 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1790 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1791 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1792 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1793 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1794 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1795 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1796 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1797 and not PDEP
# H_Abstraction
# Missing answer for RMG reaction 1802 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1814 and not PDEP
# Disproportionation
# Missing answer for RMG reaction 1814 and not PDEP
# Disproportionation

# %%
# TODO remove this to get the full uncertainty estimate
# set zeros to base_delay
for i in range(reaction_delays.shape[0]):
    if reaction_delays[i, 0] == 0:
        reaction_delays[i, :] = base_rmg7

# %%
np.where(reaction_delays == 0)
# Out:
# (array([  14,   14,   14, ..., 1849, 1849, 1849]),
#  array([ 0,  1,  2, ..., 13, 14, 15]))

# %%
base_rmg7[7]
# Out:
# 0.14857535

# %%
base_delays_sp_mat = np.repeat(np.matrix(base_rmg7), species_delays.shape[0], axis=0)
d_ln_Tau_sp_mat = np.log(species_delays) - np.log(base_delays_sp_mat)
d_Tau_sp_mat = species_delays - base_delays_sp_mat

base_delays_rxn_mat = np.repeat(np.matrix(base_rmg7), reaction_delays.shape[0], axis=0)
# d_ln_Tau_rxn_mat = np.log(reaction_delays) - np.log(base_delays_rxn_mat)
d_Tau_rxn_mat = reaction_delays - base_delays_rxn_mat

# %%
# set the unperturbed ones to zero:
for i in range(0, len(base_gas.reactions())):
    rmg_index = ct2rmg_rxn[i]
    
    try:
        a = reaction_list[rmg_index].kinetics.A.value
    except AttributeError:
        d_Tau_rxn_mat[i, :] = np.zeros(reaction_delays.shape[1])

# %%
np.min(np.abs(d_Tau_rxn_mat))
# Out:
# 0.0

# %%
# get the dG values
def perturb_species(species, delta):
    # takes in an RMG species object
    # change the enthalpy offset
    for poly in species.thermo.polynomials:
        new_coeffs = poly.coeffs
        new_coeffs[5] *= (1.0 + delta)
        poly.coeffs = new_coeffs

def perturb_reaction(rxn, delta):
    # takes in an RMG reaction object
    # delta is the ln(k) amount to perturb the A factor
    # delta is a multiplicative factor- units don't matter, yay!
    # does not deepycopy because there's some issues with rmgpy.reactions copying
    rxn.kinetics.A.value *= np.exp(delta)

# %%
# compute the thermo sensitivities
dG_kcal_mol = np.zeros(species_delays.shape)
delta = 0.1
for i in range(0, len(species_list)):
    perturbed_species = copy.deepcopy(species_list[i])
    perturb_species(perturbed_species, delta)
    for j in range(0, len(T7)):
        T = T7[j]
        dG_kcal_mol[i, j] = (perturbed_species.get_free_energy(T) - species_list[i].get_free_energy(T)) * 0.00239006  # to convert J/mol to kcal/mol

# %%
# compute the kinetic perturbations
dlnk_rmg = np.zeros(reaction_delays.shape)
delta = 0.1
P = 10.0 * 101325  # 10 atm
PDEP_UNCERTAINTY = 0.5
for i in range(0, len(reaction_list)):
    if type(reaction_list[i]) in [rmgpy.rmg.pdep.PDepReaction]:
        continue
    perturbed_reaction = copy.deepcopy(reaction_list[i])
    try:
        perturb_reaction(perturbed_reaction, delta)
    except AttributeError:
        continue
    for j in range(0, len(T7)):
        T = T7[j]
        dlnk_rmg[i, j] = np.log(perturbed_reaction.get_rate_coefficient(T, P)) - np.log(reaction_list[i].get_rate_coefficient(T, P))

# %%
# convert from rmg matrix to cantera matrix
dlnk_ct = np.zeros((len(base_gas.reactions()), reaction_delays.shape[1]))
for i in range(len(base_gas.reactions())):
    rmg_index = ct2rmg_rxn[i]
    dlnk_ct[i, :] = dlnk_rmg[rmg_index, :]

# %%
# compute average dlnk
nonzero_idx = np.where(dlnk_ct != 0)[0] 
len(np.where(dlnk_ct != 0)[0])

average_dlnk = np.average(dlnk_ct[nonzero_idx])

print(average_dlnk)
# total
# for i in range(0, dlnk_ct.shape[0]):
# Out:
# 0.10000000000000034

# %%
# thermo_sensitivity_squared = np.float_power(d_ln_Tau_mat, 2.0)
thermo_sensitivity_squared = np.float_power(d_Tau_sp_mat, 2.0)
dG_squared = np.float_power(dG_kcal_mol, 2.0)
species_uncertainty_squared_mat = np.float_power(np.repeat(np.matrix(thermo_uncertainties_rmg).transpose(), len(concentrations), axis=1), 2.0)

total_thermo_uncertainty = np.sum(np.multiply(np.divide(thermo_sensitivity_squared, dG_squared), species_uncertainty_squared_mat), axis=0)


# kinetic_sensitivity_squared = np.float_power(d_ln_Tau_rxn_mat, 2.0)
kinetic_sensitivity_squared = np.float_power(d_Tau_rxn_mat, 2.0)
# set zero dlnk values to 0.1
dlnk_ct[np.where(dlnk_ct == 0)[0]] = 0.1
dlnk_squared = np.float_power(dlnk_ct, 2.0)

# change the zeros to the average nonzero value

reaction_uncertainty_squared_mat = np.float_power(np.repeat(np.matrix(kinetic_uncertainties_ct).transpose(), len(concentrations), axis=1), 2.0)
# reaction_uncertainty_squared_mat = np.repeat(np.matrix(kinetic_uncertainties_ct).transpose(), len(concentrations), axis=1)  # it's already been squared
partial_kinetic_uncertainties = np.multiply(np.divide(kinetic_sensitivity_squared, dlnk_squared), reaction_uncertainty_squared_mat)
total_kinetic_uncertainty = np.sum(np.multiply(np.divide(kinetic_sensitivity_squared, dlnk_squared), reaction_uncertainty_squared_mat), axis=0)

# %%
total_thermo_uncertainty
# Out:
# matrix([[1.00249753e-03, 9.53830813e-04, 4.31816073e-04, 4.34884371e-04,
#          6.39478665e-04, 6.46229826e-04, 3.68343280e-04, 3.53612158e-04,
#          3.09952570e-05, 1.81248565e-05, 4.70229365e-06, 2.83676000e-06,
#          7.83567359e-07, 3.32725608e-07, 2.97542925e-07, 1.29553454e-07]])

# %%
total_kinetic_uncertainty
# Out:
# matrix([[0.00279928, 0.00284132, 0.00877253, 0.0092753 , 0.03954318,
#          0.04189952, 0.06726155, 0.06475841, 0.00584422, 0.00361991,
#          0.00130814, 0.00095082, 0.00044866, 0.00026242, 0.00024272,
#          0.00011467]])

# %%
lower_bound = base_rmg7 - total_thermo_uncertainty - total_kinetic_uncertainty
upper_bound = base_rmg7 + total_thermo_uncertainty + total_kinetic_uncertainty

# %%
total_thermo_uncertainty
# Out:
# matrix([[1.00249753e-03, 9.53830813e-04, 4.31816073e-04, 4.34884371e-04,
#          6.39478665e-04, 6.46229826e-04, 3.68343280e-04, 3.53612158e-04,
#          3.09952570e-05, 1.81248565e-05, 4.70229365e-06, 2.83676000e-06,
#          7.83567359e-07, 3.32725608e-07, 2.97542925e-07, 1.29553454e-07]])

# %%
# put error bars on the plot

# plot the ignition delay
plt.plot(1000.0 / T7, base_rmg7, marker='x', linestyle='dashed')
plt.plot(1000.0 / T7, aramco7, marker='x')
plt.scatter(1000.0 / T7, tau7 / 1000.0, color='black')

plt.plot(1000.0 / T7, lower_bound.transpose(), color='blue')
plt.plot(1000.0 / T7, upper_bound.transpose(), color='blue')

ax = plt.gca()
ax.set_yscale('log')
plt.legend(['Base RMG', 'Aramco', 'Experiment'])
plt.title('Ignition Delays Phi=1.0')
plt.xlabel('1000K / T')
plt.ylabel('Delay (s)')
plt.savefig('table7.png')
# plt.legend(bbox_to_anchor=(0, 1), , ncol=1)

# %%
len(concentrations)
# Out:
# 16
